# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasit-18-02/module-1-lab-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('test git and colab')
